# %% [markdown]
# <a href="https://colab.research.google.com/github/dwp28/Prueba_git/blob/main/Github_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRUEBA

# %%
# !git clone https://github.com/dwp28/Prueba_git
# Out:
# Cloning into 'Prueba_git'...
# remote: Enumerating objects: 64, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 64 (delta 13), reused 41 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (64/64), 12.97 KiB | 781.00 KiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !ls
# Out:
# Prueba_git  sample_data
